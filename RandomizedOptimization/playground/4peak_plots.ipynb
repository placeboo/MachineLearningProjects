# %%
import os
os.chdir('../')
print(os.getcwd())
# Out:
# /Users/Placebo/OMSCS/CS7641-ML/MachineLearningProjects/RandomizedOptimization

# %%
# %load_ext autoreload
# %autoreload 2
from src.utils import save_results, plot_performance_vs_size, plot_iterations_vs_time, plot_fitness_vs_iteration, load_results, parse_fitness_curve, set_plot_style, save_plot, plot_fitness_vs_iteration_wsize, plot_parameter_vs_metric, plot_fitness_curve_with_params
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Four Peaks Size

# %%
results_dir = 'results/fourpeaks/size_experiment'
fig_dir = 'figures/fourpeaks/size_experiment'

# %%
results = load_results('fourpeaks_size', results_dir)

# %%
plot_fitness_vs_iteration_wsize(results,90, fig_dir)
# Out:
# Plot saved as figures/fourpeaks/size_experiment/fitness_vs_iteration_90_vs_problem_size.png

# %%
plot_performance_vs_size(results, 'best_fitness', fig_dir)
# Out:
# Plot saved as figures/fourpeaks/size_experiment/best_fitness_vs_size_vs_problem_size.png

# %%
plot_performance_vs_size(results, 'execution_time', fig_dir)
# Out:
# Plot saved as figures/fourpeaks/size_experiment/execution_time_vs_size_vs_problem_size.png

# %%
plot_iterations_vs_time(results, fig_dir)
# Out:
# Plot saved as figures/fourpeaks/size_experiment/iterations_vs_time_vs_problem_size.png

# %%
results
# Out:
#     problem_size algorithm  best_fitness  execution_time  \
# 0             10       RHC          18.0        0.016324
# 1             10        SA          18.0        0.004394
# 2             10        GA          18.0        0.419914
# 3             10     MIMIC          18.0        1.596167
# 4             20       RHC          37.0        0.030039
# 5             20        SA          37.0        0.004760
# 6             20        GA          37.0        0.457105
# 7             20     MIMIC          37.0        6.512106
# 8             30       RHC          56.0        0.037052
# 9             30        SA          56.0        0.007070
# 10            30        GA          56.0        0.634219
# 11            30     MIMIC          52.0       13.756404
# 12            40       RHC          75.0        0.053426
# 13            40        SA          75.0        0.014035
# 14            40        GA          75.0        0.636565
# 15            40     MIMIC          75.0       25.533293
# 16            50       RHC          50.0        0.042791
# 17            50        SA          94.0        0.016901
# 18            50        GA          94.0        0.749212
# 19            50     MIMIC          73.0       41.895964
# 20            60       RHC          26.0        0.029238
# 21            60        SA         104.0        0.017631
# 22            60        GA         113.0        0.719622
# 23            60     MIMIC          90.0       56.453169
# 24            70       RHC          15.0        0.023574
# 25            70        SA          41.0        0.019166
# 26            70        GA         132.0        0.805170
# 27            70     MIMIC         111.0      101.081256
# 28            80       RHC          25.0        0.022512
# 29            80        SA          23.0        0.020229
# 30            80        GA         151.0        1.629620
# 31            80     MIMIC          89.0       89.693538
# 32            90       RHC          17.0        0.022626
# 33            90        SA          19.0        0.020502
# 34            90        GA         170.0        1.229863
# 35            90     MIMIC         116.0      124.844022
# 36           100       RHC          20.0        0.021665
# 37           100        SA          18.0        0.021533
# 38           100        GA         100.0        2.062792
# 39           100     MIMIC         118.0      149.727029
# 40           110       RHC          25.0        0.024172
# 41           110        SA          21.0        0.021154
# 42           110        GA         110.0        2.171151
# 43           110     MIMIC         134.0      211.461955
# 44           120       RHC          12.0        0.019683
# 45           120        SA          13.0        0.021733
# 46           120        GA         227.0        3.080700
# 47           120     MIMIC          24.0      305.013453
# 48           130       RHC          19.0        0.031535
# 49           130        SA          14.0        0.021869
# 50           130        GA         246.0        2.728140
# 51           130     MIMIC          32.0      251.200495
# 52           140       RHC          13.0        0.017016
# 53           140        SA          24.0        0.022264
# 54           140        GA         140.0        3.678241
# 55           140     MIMIC         171.0      329.528573
# 56           150       RHC          17.0        0.026419
# 57           150        SA          11.0        0.022052
# 58           150        GA         143.0        4.381447
# 59           150     MIMIC          20.0      339.940441
#
#                                         fitness_curve  iterations
# 0   [[0.0, 1.0], [0.0, 2.0], [0.0, 3.0], [0.0, 4.0...         118
# 1   [[0.0, 2.0], [0.0, 4.0], [0.0, 6.0], [0.0, 8.0...         284
# 2   [[18.0, 402.0], [18.0, 603.0], [18.0, 804.0], ...         101
# 3   [[18.0, 402.0], [18.0, 603.0], [18.0, 804.0], ...         101
# 4   [[0.0, 1182.0], [0.0, 1183.0], [0.0, 1184.0], ...         328
# 5   [[1.0, 2.0], [1.0, 4.0], [1.0, 6.0], [1.0, 8.0...         266
# 6   [[31.0, 402.0], [31.0, 603.0], [31.0, 804.0], ...         108
# 7   [[28.0, 402.0], [32.0, 604.0], [32.0, 805.0], ...         122
# 8   [[0.0, 2575.0], [0.0, 2576.0], [0.0, 2577.0], ...         472
# 9   [[0.0, 2.0], [0.0, 4.0], [0.0, 6.0], [0.0, 8.0...         441
# 10  [[36.0, 402.0], [37.0, 604.0], [43.0, 806.0], ...         155
# 11  [[36.0, 402.0], [40.0, 604.0], [41.0, 806.0], ...         113
# 12  [[2.0, 2738.0], [2.0, 2739.0], [2.0, 2740.0], ...         570
# 13  [[3.0, 2.0], [3.0, 4.0], [3.0, 6.0], [3.0, 8.0...         880
# 14  [[48.0, 402.0], [52.0, 604.0], [56.0, 806.0], ...         153
# 15  [[49.0, 402.0], [49.0, 603.0], [53.0, 805.0], ...         118
# 16  [[0.0, 1571.0], [0.0, 1572.0], [0.0, 1573.0], ...         772
# 17  [[0.0, 2.0], [0.0, 4.0], [0.0, 6.0], [0.0, 8.0...         951
# 18  [[11.0, 402.0], [11.0, 603.0], [11.0, 804.0], ...         171
# 19  [[10.0, 402.0], [57.0, 604.0], [57.0, 805.0], ...         121
# 20  [[3.0, 155.0], [3.0, 156.0], [3.0, 157.0], [3....         326
# 21  [[3.0, 2.0], [3.0, 4.0], [3.0, 6.0], [3.0, 8.0...        1000
# 22  [[10.0, 402.0], [12.0, 604.0], [12.0, 805.0], ...         167
# 23  [[11.0, 402.0], [13.0, 604.0], [69.0, 806.0], ...         116
# 24  [[0.0, 507.0], [2.0, 509.0], [3.0, 511.0], [3....         263
# 25  [[0.0, 2.0], [0.0, 4.0], [0.0, 6.0], [0.0, 8.0...        1000
# 26  [[80.0, 402.0], [81.0, 604.0], [82.0, 806.0], ...         190
# 27  [[13.0, 402.0], [14.0, 604.0], [80.0, 806.0], ...         148
# 28  [[8.0, 1627.0], [8.0, 1628.0], [8.0, 1629.0], ...         446
# 29  [[0.0, 2.0], [0.0, 4.0], [0.0, 6.0], [0.0, 8.0...        1000
# 30  [[8.0, 402.0], [12.0, 604.0], [12.0, 805.0], [...         392
# 31  [[10.0, 402.0], [13.0, 604.0], [13.0, 805.0], ...         104
# 32  [[2.0, 1585.0], [2.0, 1586.0], [2.0, 1587.0], ...         335
# 33  [[0.0, 2.0], [0.0, 4.0], [0.0, 6.0], [0.0, 8.0...        1000
# 34  [[10.0, 402.0], [10.0, 603.0], [11.0, 805.0], ...         295
# 35  [[10.0, 402.0], [14.0, 604.0], [14.0, 805.0], ...         113
# 36  [[1.0, 189.0], [1.0, 190.0], [1.0, 191.0], [1....         542
# 37  [[1.0, 2.0], [1.0, 4.0], [1.0, 6.0], [1.0, 8.0...        1000
# 38  [[10.0, 402.0], [12.0, 604.0], [16.0, 806.0], ...         486
# 39  [[11.0, 402.0], [11.0, 603.0], [15.0, 805.0], ...         109
# 40  [[1.0, 583.0], [1.0, 584.0], [1.0, 585.0], [1....         722
# 41  [[1.0, 2.0], [1.0, 4.0], [1.0, 6.0], [1.0, 8.0...        1000
# 42  [[13.0, 402.0], [13.0, 603.0], [13.0, 804.0], ...         483
# 43  [[14.0, 402.0], [14.0, 603.0], [16.0, 805.0], ...         126
# 44  [[0.0, 185.0], [2.0, 187.0], [2.0, 188.0], [2....         296
# 45  [[1.0, 2.0], [1.0, 4.0], [1.0, 6.0], [1.0, 8.0...        1000
# 46  [[10.0, 402.0], [11.0, 604.0], [18.0, 806.0], ...         709
# 47  [[11.0, 402.0], [13.0, 604.0], [14.0, 806.0], ...         154
# 48  [[0.0, 578.0], [0.0, 579.0], [0.0, 580.0], [0....         375
# 49  [[0.0, 2.0], [0.0, 4.0], [0.0, 6.0], [0.0, 8.0...        1000
# 50  [[13.0, 402.0], [13.0, 603.0], [13.0, 804.0], ...         627
# 51  [[11.0, 402.0], [13.0, 604.0], [13.0, 805.0], ...         109
# 52  [[9.0, 1.0], [9.0, 2.0], [9.0, 3.0], [9.0, 4.0...         187
# 53  [[9.0, 2.0], [4.0, 4.0], [4.0, 5.0], [9.0, 7.0...        1000
# 54  [[11.0, 402.0], [11.0, 603.0], [11.0, 804.0], ...         814
# 55  [[9.0, 401.0], [13.0, 603.0], [18.0, 805.0], [...         124
# 56  [[2.0, 161.0], [2.0, 162.0], [2.0, 163.0], [2....         499
# 57  [[0.0, 2.0], [0.0, 4.0], [0.0, 6.0], [0.0, 8.0...        1000
# 58  [[10.0, 402.0], [13.0, 604.0], [13.0, 805.0], ...        1000
# 59  [[9.0, 402.0], [13.0, 604.0], [13.0, 805.0], [...         110

# %% [markdown]
# # Hyperparameter tuning

# %%
results_dir = 'results/fourpeaks/hyperparameter_experiment_size_50'
fig_dir = 'figures/fourpeaks/hyperparameter_experiment_size_50'

# %%
results = load_results('fourpeaks_hyperparameter_size_50', results_dir)

# %%
results
# Out:
#     problem_size algorithm  best_fitness  execution_time  \
# 0             50       RHC          10.0        0.023783
# 1             50       RHC          50.0        0.046928
# 2             50       RHC          50.0        0.082964
# 3             50        SA          82.0        0.016561
# 4             50        SA          87.0        0.018196
# 5             50        SA          87.0        0.017999
# 6             50        SA          87.0        0.018233
# 7             50        SA          82.0        0.011714
# 8             50        SA          86.0        0.014615
# 9             50        SA          94.0        0.016141
# 10            50        SA          94.0        0.016673
# 11            50        SA          82.0        0.012547
# 12            50        SA          86.0        0.015456
# 13            50        SA          94.0        0.016667
# 14            50        SA          94.0        0.017234
# 15            50        GA          73.0        0.079238
# 16            50        GA          86.0        0.172325
# 17            50        GA          65.0        0.060997
# 18            50        GA          89.0        0.134206
# 19            50        GA          92.0        0.291061
# 20            50        GA          94.0        0.334723
# 21            50        GA          94.0        0.296600
# 22            50        GA          94.0        0.312289
# 23            50        GA          81.0        0.377652
# 24            50        GA          94.0        0.576321
# 25            50        GA          94.0        0.457794
# 26            50        GA          94.0        0.723455
# 27            50     MIMIC          71.0        7.102665
# 28            50     MIMIC          60.0        4.429171
# 29            50     MIMIC          59.0        5.567180
# 30            50     MIMIC          59.0        7.033069
# 31            50     MIMIC          80.0        7.220237
# 32            50     MIMIC          73.0       10.468848
# 33            50     MIMIC          67.0        7.994509
# 34            50     MIMIC          71.0        9.049424
# 35            50     MIMIC          89.0        9.086182
# 36            50     MIMIC          75.0        8.680273
# 37            50     MIMIC          66.0       11.972790
# 38            50     MIMIC          67.0        5.298591
#
#                                         fitness_curve  iterations  run  \
# 0   [[0.0, 1.0], [0.0, 2.0], [0.0, 3.0], [0.0, 4.0...         464    0
# 1   [[0.0, 1571.0], [0.0, 1572.0], [0.0, 1573.0], ...         772    0
# 2   [[0.0, 1571.0], [0.0, 1572.0], [0.0, 1573.0], ...         772    0
# 3   [[0.0, 2.0], [0.0, 4.0], [0.0, 6.0], [0.0, 8.0...         871    0
# 4   [[0.0, 2.0], [0.0, 4.0], [0.0, 6.0], [0.0, 8.0...        1000    0
# 5   [[0.0, 2.0], [0.0, 4.0], [0.0, 6.0], [0.0, 8.0...        1000    0
# 6   [[0.0, 2.0], [0.0, 4.0], [0.0, 6.0], [0.0, 8.0...        1000    0
# 7   [[0.0, 2.0], [0.0, 4.0], [0.0, 6.0], [0.0, 8.0...         609    0
# 8   [[0.0, 2.0], [0.0, 4.0], [0.0, 6.0], [0.0, 8.0...         815    0
# 9   [[0.0, 2.0], [0.0, 4.0], [0.0, 6.0], [0.0, 8.0...         901    0
# 10  [[0.0, 2.0], [0.0, 4.0], [0.0, 6.0], [0.0, 8.0...         951    0
# 11  [[0.0, 2.0], [0.0, 4.0], [0.0, 6.0], [0.0, 8.0...         609    0
# 12  [[0.0, 2.0], [0.0, 4.0], [0.0, 6.0], [0.0, 8.0...         815    0
# 13  [[0.0, 2.0], [0.0, 4.0], [0.0, 6.0], [0.0, 8.0...         901    0
# 14  [[0.0, 2.0], [0.0, 4.0], [0.0, 6.0], [0.0, 8.0...         951    0
# 15  [[10.0, 202.0], [12.0, 304.0], [57.0, 406.0], ...          36    0
# 16  [[13.0, 202.0], [59.0, 304.0], [62.0, 406.0], ...          81    0
# 17  [[10.0, 202.0], [10.0, 303.0], [10.0, 404.0], ...          27    0
# 18  [[10.0, 202.0], [10.0, 303.0], [11.0, 405.0], ...          57    0
# 19  [[11.0, 402.0], [11.0, 603.0], [11.0, 804.0], ...          62    0
# 20  [[13.0, 402.0], [13.0, 603.0], [14.0, 805.0], ...          71    0
# 21  [[12.0, 402.0], [12.0, 603.0], [59.0, 805.0], ...          62    0
# 22  [[10.0, 402.0], [58.0, 604.0], [58.0, 805.0], ...          66    0
# 23  [[10.0, 802.0], [61.0, 1204.0], [62.0, 1606.0]...          41    0
# 24  [[57.0, 802.0], [60.0, 1204.0], [63.0, 1606.0]...          61    0
# 25  [[10.0, 802.0], [12.0, 1204.0], [57.0, 1606.0]...          44    0
# 26  [[10.0, 802.0], [12.0, 1204.0], [60.0, 1606.0]...          65    0
# 27  [[63.0, 202.0], [63.0, 303.0], [63.0, 404.0], ...          21    0
# 28  [[9.0, 202.0], [9.0, 303.0], [60.0, 405.0], [6...          13    0
# 29  [[9.0, 202.0], [10.0, 304.0], [10.0, 405.0], [...          16    0
# 30  [[9.0, 202.0], [10.0, 304.0], [10.0, 405.0], [...          21    0
# 31  [[10.0, 402.0], [59.0, 604.0], [63.0, 806.0], ...          22    0
# 32  [[10.0, 402.0], [57.0, 604.0], [57.0, 805.0], ...          31    0
# 33  [[8.0, 402.0], [10.0, 604.0], [10.0, 805.0], [...          24    0
# 34  [[8.0, 402.0], [10.0, 604.0], [10.0, 805.0], [...          27    0
# 35  [[58.0, 802.0], [63.0, 1204.0], [63.0, 1605.0]...          27    0
# 36  [[9.0, 802.0], [57.0, 1204.0], [61.0, 1606.0],...          25    0
# 37  [[10.0, 802.0], [11.0, 1204.0], [59.0, 1606.0]...          34    0
# 38  [[10.0, 802.0], [11.0, 1204.0], [59.0, 1606.0]...          15    0
#
#     param_restarts  param_max_attempts  param_max_iters  param_random_state  \
# 0              5.0               100.0             1000                  42
# 1             10.0               100.0             1000                  42
# 2             20.0               100.0             1000                  42
# 3              NaN                10.0             1000                  42
# 4              NaN                20.0             1000                  42
# 5              NaN                50.0             1000                  42
# 6              NaN               100.0             1000                  42
# 7              NaN                10.0             1000                  42
# 8              NaN                20.0             1000                  42
# 9              NaN                50.0             1000                  42
# 10             NaN               100.0             1000                  42
# 11             NaN                10.0             1000                  42
# 12             NaN                20.0             1000                  42
# 13             NaN                50.0             1000                  42
# 14             NaN               100.0             1000                  42
# 15             NaN                 NaN             1000                  42
# 16             NaN                 NaN             1000                  42
# 17             NaN                 NaN             1000                  42
# 18             NaN                 NaN             1000                  42
# 19             NaN                 NaN             1000                  42
# 20             NaN                 NaN             1000                  42
# 21             NaN                 NaN             1000                  42
# 22             NaN                 NaN             1000                  42
# 23             NaN                 NaN             1000                  42
# 24             NaN                 NaN             1000                  42
# 25             NaN                 NaN             1000                  42
# 26             NaN                 NaN             1000                  42
# 27             NaN                 NaN             1000                  42
# 28             NaN                 NaN             1000                  42
# 29             NaN                 NaN             1000                  42
# 30             NaN                 NaN             1000                  42
# 31             NaN                 NaN             1000                  42
# 32             NaN                 NaN             1000                  42
# 33             NaN                 NaN             1000                  42
# 34             NaN                 NaN             1000                  42
# 35             NaN                 NaN             1000                  42
# 36             NaN                 NaN             1000                  42
# 37             NaN                 NaN             1000                  42
# 38             NaN                 NaN             1000                  42
#
#                                        param_schedule  param_pop_size  \
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                                                 NaN             NaN
# 3   ArithDecay(init_temp=1.0, decay=0.0001, min_te...             NaN
# 4   ArithDecay(init_temp=1.0, decay=0.0001, min_te...             NaN
# 5   ArithDecay(init_temp=1.0, decay=0.0001, min_te...             NaN
# 6   ArithDecay(init_temp=1.0, decay=0.0001, min_te...             NaN
# 7                                                 1.0             NaN
# 8                                                 1.0             NaN
# 9                                                 1.0             NaN
# 10                                                1.0             NaN
# 11  ExpDecay(init_temp=1.0, exp_const=0.005, min_t...             NaN
# 12  ExpDecay(init_temp=1.0, exp_const=0.005, min_t...             NaN
# 13  ExpDecay(init_temp=1.0, exp_const=0.005, min_t...             NaN
# 14  ExpDecay(init_temp=1.0, exp_const=0.005, min_t...             NaN
# 15                                                NaN           100.0
# 16                                                NaN           100.0
# 17                                                NaN           100.0
# 18                                                NaN           100.0
# 19                                                NaN           200.0
# 20                                                NaN           200.0
# 21                                                NaN           200.0
# 22                                                NaN           200.0
# 23                                                NaN           400.0
# 24                                                NaN           400.0
# 25                                                NaN           400.0
# 26                                                NaN           400.0
# 27                                                NaN           100.0
# 28                                                NaN           100.0
# 29                                                NaN           100.0
# 30                                                NaN           100.0
# 31                                                NaN           200.0
# 32                                                NaN           200.0
# 33                                                NaN           200.0
# 34                                                NaN           200.0
# 35                                                NaN           400.0
# 36                                                NaN           400.0
# 37                                                NaN           400.0
# 38                                                NaN           400.0
#
#     param_mutation_prob  param_keep_pct
# 0                   NaN             NaN
# 1                   NaN             NaN
# 2                   NaN             NaN
# 3                   NaN             NaN
# 4                   NaN             NaN
# 5                   NaN             NaN
# 6                   NaN             NaN
# 7                   NaN             NaN
# 8                   NaN             NaN
# 9                   NaN             NaN
# 10                  NaN             NaN
# 11                  NaN             NaN
# 12                  NaN             NaN
# 13                  NaN             NaN
# 14                  NaN             NaN
# 15                  0.1             NaN
# 16                  0.2             NaN
# 17                  0.3             NaN
# 18                  0.4             NaN
# 19                  0.1             NaN
# 20                  0.2             NaN
# 21                  0.3             NaN
# 22                  0.4             NaN
# 23                  0.1             NaN
# 24                  0.2             NaN
# 25                  0.3             NaN
# 26                  0.4             NaN
# 27                  NaN             0.1
# 28                  NaN             0.2
# 29                  NaN             0.3
# 30                  NaN             0.4
# 31                  NaN             0.1
# 32                  NaN             0.2
# 33                  NaN             0.3
# 34                  NaN             0.4
# 35                  NaN             0.1
# 36                  NaN             0.2
# 37                  NaN             0.3
# 38                  NaN             0.4

# %% [markdown]
# ## RHC

# %%
plot_parameter_vs_metric(
    df=results,
    algorithm='RHC',
    primary_param='param_restarts',
    metric='best_fitness',
    output_dir=fig_dir
)
plot_parameter_vs_metric(
    df=results,
    algorithm='RHC',
    primary_param='param_restarts',
    metric='execution_time',
    output_dir=fig_dir
)
plot_fitness_curve_with_params(
    df = results,
    algorithm='RHC',
    params = ['restarts'],
    output_dir=fig_dir
)
# Out:
# Plot saved as figures/fourpeaks/hyperparameter_experiment_size_50/RHC_best_fitness_vs_param_restarts_vs_problem_size.png
# Plot saved as figures/fourpeaks/hyperparameter_experiment_size_50/RHC_execution_time_vs_param_restarts_vs_problem_size.png
# Plot saved as figures/fourpeaks/hyperparameter_experiment_size_50/RHC_fitness_curves_vs_problem_size.png

# %% [markdown]
# ## SA

# %%
plot_parameter_vs_metric(
    df=results,
    algorithm='SA',
    primary_param='param_max_attempts',
    secondary_param='param_schedule',
    metric='best_fitness',
    output_dir=fig_dir
)
plot_parameter_vs_metric(
    df=results,
    algorithm='SA',
    primary_param='param_max_attempts',
    secondary_param='param_schedule',
    metric='execution_time',
    output_dir=fig_dir
)
sub_results = results[results['param_max_attempts'] == 100]
plot_fitness_curve_with_params(
    df = sub_results,
    algorithm='SA',
    params = ['schedule'],
    output_dir=fig_dir
)
# Out:
# /Users/Placebo/OMSCS/CS7641-ML/MachineLearningProjects/RandomizedOptimization/src/utils.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alg_df[param] = alg_df[param].apply(lambda x: 'GeomDecay' if str(x) == '1.0' else str(x).split('(')[0])
# /Users/Placebo/OMSCS/CS7641-ML/MachineLearningProjects/RandomizedOptimization/src/utils.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alg_df[param] = alg_df[param].apply(lambda x: 'GeomDecay' if str(x) == '1.0' else str(x).split('(')[0])
# Plot saved as figures/fourpeaks/hyperparameter_experiment_size_50/SA_best_fitness_vs_param_max_attempts_vs_problem_size.png
# Plot saved as figures/fourpeaks/hyperparameter_experiment_size_50/SA_execution_time_vs_param_max_attempts_vs_problem_size.png
# Plot saved as figures/fourpeaks/hyperparameter_experiment_size_50/SA_fitness_curves_vs_problem_size.png

# %% [markdown]
# ## GA

# %%
plot_parameter_vs_metric(
    df=results,
    algorithm='GA',
    primary_param='param_pop_size',
    secondary_param='param_mutation_prob',
    metric='best_fitness',
    output_dir=fig_dir
)
plot_parameter_vs_metric(
    df=results,
    algorithm='GA',
    primary_param='param_pop_size',
    secondary_param='param_mutation_prob',
    metric='execution_time',
    output_dir=fig_dir
)
plot_parameter_vs_metric(
    df=results,
    algorithm='GA',
    primary_param='param_mutation_prob',
    secondary_param='param_pop_size',
    metric='best_fitness',
    output_dir=fig_dir
)
plot_parameter_vs_metric(
    df=results,
    algorithm='GA',
    primary_param='param_mutation_prob',
    secondary_param='param_pop_size',
    metric='execution_time',
    output_dir=fig_dir
)
# Out:
# Plot saved as figures/fourpeaks/hyperparameter_experiment_size_50/GA_best_fitness_vs_param_pop_size_vs_problem_size.png
# Plot saved as figures/fourpeaks/hyperparameter_experiment_size_50/GA_execution_time_vs_param_pop_size_vs_problem_size.png
# Plot saved as figures/fourpeaks/hyperparameter_experiment_size_50/GA_best_fitness_vs_param_mutation_prob_vs_problem_size.png
# Plot saved as figures/fourpeaks/hyperparameter_experiment_size_50/GA_execution_time_vs_param_mutation_prob_vs_problem_size.png

# %%
sub_results = results[results['param_mutation_prob'] == 0.2]
plot_fitness_curve_with_params(
    df = sub_results,
    algorithm='GA',
    params = ['pop_size'],
    output_dir=fig_dir
)
# sub_results = results[results['param_mutation_prob'] == 0.2]
# plot_fitness_curve_with_params(
#     df = sub_results,
#     algorithm='GA',
#     params = ['pop_size'],
#     output_dir=fig_dir
# )
# Out:
# Plot saved as figures/fourpeaks/hyperparameter_experiment_size_50/GA_fitness_curves_vs_problem_size.png

# %% [markdown]
# ## MIMIC

# %%
plot_parameter_vs_metric(
    df=results,
    algorithm='MIMIC',
    primary_param='param_pop_size',
    secondary_param='param_keep_pct',
    metric='best_fitness',
    output_dir=fig_dir
)
plot_parameter_vs_metric(
    df=results,
    algorithm='MIMIC',
    primary_param='param_pop_size',
    secondary_param='param_keep_pct',
    metric='execution_time',
    output_dir=fig_dir
)
plot_parameter_vs_metric(
    df=results,
    algorithm='MIMIC',
    primary_param='param_keep_pct',
    secondary_param='param_pop_size',
    metric='best_fitness',
    output_dir=fig_dir
)
plot_parameter_vs_metric(
    df=results,
    algorithm='MIMIC',
    primary_param='param_keep_pct',
    secondary_param='param_pop_size',
    metric='execution_time',
    output_dir=fig_dir
)
# Out:
# Plot saved as figures/fourpeaks/hyperparameter_experiment_size_50/MIMIC_best_fitness_vs_param_pop_size_vs_problem_size.png
# Plot saved as figures/fourpeaks/hyperparameter_experiment_size_50/MIMIC_execution_time_vs_param_pop_size_vs_problem_size.png
# Plot saved as figures/fourpeaks/hyperparameter_experiment_size_50/MIMIC_best_fitness_vs_param_keep_pct_vs_problem_size.png
# Plot saved as figures/fourpeaks/hyperparameter_experiment_size_50/MIMIC_execution_time_vs_param_keep_pct_vs_problem_size.png

# %%
sub_results = results[results['param_pop_size'] == 200]
plot_fitness_curve_with_params(
    df = sub_results,
    algorithm='MIMIC',
    params = ['keep_pct'],
    output_dir=fig_dir
)
# Out:
# Plot saved as figures/fourpeaks/hyperparameter_experiment_size_50/MIMIC_fitness_curves_vs_problem_size.png
